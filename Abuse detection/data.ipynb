# %%
import pandas_profiling
import nltk
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt 
import seaborn as sb
from nltk.corpus import stopwords
import warnings 
warnings.filterwarnings("ignore")
import unidecode
from wordcloud import WordCloud
from nltk.stem import WordNetLemmatizer 
nltk.download('wordnet')
from nltk.stem import PorterStemmer
nltk.download('punkt')
from nltk.tokenize import word_tokenize 
import matplotlib.animation as animation
import operator
import plotly.express as px
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer

# %matplotlib inline
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\anush\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anush\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('mydataset.csv')

# %%
df.head(202)
# Out:
#                                                   text  value
# 0     मोदी क्या आये दीदी पटेल बोस भगत सिंह राज गुरु...      0
# 1                                    है कौन ये मादरचोद      1
# 2    आस्था के महापर्व छठी मे जो माँ अपने बच्चों के ...      0
# 3    वर्ष   में भारत सरकार द्वारा   अक्टूबर को प्रत...      0
# 4    केजरीवाल सरकार जो फ्री टिकट देने का ढिंढोरा पी...      0
# ..                                                 ...    ...
# 197                     chudaikhana bna rkha h salo ne      1
# 198  jhaat bhr ki aukad nhi aajte h gand marane gaa...      1
# 199  Haram ki kamai aur acche waqt me guroor ni kar...      0
# 200                              kameeni aurat chup kr      1
# 201  कटी हुई लुल्ली से इतने पैदा करते है ये लोग.......      1
#
# [202 rows x 2 columns]

# %%
pandas_profiling.ProfileReport(df)

# %%
df.head()
# Out:
#                                                 text  value
# 0   मोदी क्या आये दीदी पटेल बोस भगत सिंह राज गुरु...      0
# 1                                  है कौन ये मादरचोद      1
# 2  आस्था के महापर्व छठी मे जो माँ अपने बच्चों के ...      0
# 3  वर्ष   में भारत सरकार द्वारा   अक्टूबर को प्रत...      0
# 4  केजरीवाल सरकार जो फ्री टिकट देने का ढिंढोरा पी...      0

# %%
df.shape
# Out:
# (203, 2)

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (203, 2)

# %%
df['text'].isna().sum()
# Out:
# 0

# %%
df['value'].isna().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (203, 2)

# %%
#Code to remove @
df['clean_tweet'] = df['text'].apply(lambda x : ' '.join([text for text in x.split()if not text.startswith("@")]))

# %%
df.head(126)
# Out:
#                                                   text  value  \
# 0     मोदी क्या आये दीदी पटेल बोस भगत सिंह राज गुरु...      0
# 1                                    है कौन ये मादरचोद      1
# 2    आस्था के महापर्व छठी मे जो माँ अपने बच्चों के ...      0
# 3    वर्ष   में भारत सरकार द्वारा   अक्टूबर को प्रत...      0
# 4    केजरीवाल सरकार जो फ्री टिकट देने का ढिंढोरा पी...      0
# ..                                                 ...    ...
# 121      i txt my old bitch my new bitch pussy wetter       1
# 122                   wear pushup bra for boob support      0
# 123             meow meow pussy cat pussy cat come in       0
# 124       momma said no pussy cats inside my doghouse       0
# 125  Why the eggplant @aah emoji doe y he say she l...      0
#
#                                            clean_tweet
# 0    मोदी क्या आये दीदी पटेल बोस भगत सिंह राज गुरु ...
# 1                                    है कौन ये मादरचोद
# 2    आस्था के महापर्व छठी मे जो माँ अपने बच्चों के ...
# 3    वर्ष में भारत सरकार द्वारा अक्टूबर को प्रतिवर्...
# 4    केजरीवाल सरकार जो फ्री टिकट देने का ढिंढोरा पी...
# ..                                                 ...
# 121       i txt my old bitch my new bitch pussy wetter
# 122                   wear pushup bra for boob support
# 123              meow meow pussy cat pussy cat come in
# 124        momma said no pussy cats inside my doghouse
# 125  Why the eggplant emoji doe y he say she looked...
#
# [126 rows x 3 columns]

# %%
#Removing all the greek characters using unidecode library

df['clean_tweet'] = df['clean_tweet'].apply(lambda x : ' '.join([unidecode.unidecode(word) for word in x.split()]))

# %%
  df["clean_tweet"] = df['clean_tweet'].str.replace('[^\w\s]','')

# %%
df.head()
# Out:
#                                                 text  value  \
# 0   मोदी क्या आये दीदी पटेल बोस भगत सिंह राज गुरु...      0
# 1                                  है कौन ये मादरचोद      1
# 2  आस्था के महापर्व छठी मे जो माँ अपने बच्चों के ...      0
# 3  वर्ष   में भारत सरकार द्वारा   अक्टूबर को प्रत...      0
# 4  केजरीवाल सरकार जो फ्री टिकट देने का ढिंढोरा पी...      0
#
#                                          clean_tweet
# 0  modii kyaa aaye diidii pttel bos bhgt siNh raa...
# 1                               hai kaun ye maadrcod
# 2  aasthaa ke mhaaprv chtthii me jo maaN apne bcc...
# 3  vrss meN bhaart srkaar dvaaraa akttuubr ko prt...
# 4  kejriivaal srkaar jo phrii ttiktt dene kaa ddh...

# %%
#Removing the word 'hmm' and it's variants
df['clean_tweet'] = df['clean_tweet'].apply(lambda x : ' '.join([word for word in x.split() if not word == 'h(m)+' ]))
df['clean_tweet'] = df['clean_tweet'].apply(lambda x : ' '.join([word for word in x.split() if not word == 'ky(a)+' ]))
df['clean_tweet'] = df['clean_tweet'].apply(lambda x : ' '.join([word for word in x.split() if not word == 'mod(i)+' ]))
df['clean_tweet'] = df['clean_tweet'].apply(lambda x : ' '.join([word for word in x.split() if not word == 'k(i)+' ]))

# %%
import string
df['clean_tweet'] = df['clean_tweet'].str.replace('\d+', '')
df['clean_tweet'] = df['clean_tweet'].str.replace('_', '')

# %%
df['clean_tweet'][202]
# Out:
# 'jai shriiraam bol bhncod https twittercomNationalVoice status'

# %%
#Code for removing slang words
d = {'luv':'love','wud':'would','wnna':'want','lyk':'like','uh':'you','wateva':'whatever','ttyl':'talk to you later','kul':'cool','fyn':'fine','omg':'oh my god!','fam':'family','bruh':'brother','F.O.':'fuck off',
'cud':'could','fud':'food'} ## Need a huge dictionary
words = "i luv uh"
words = words.split()
reformed = [d[word] if word in d else word for word in words]
reformed = " ".join(reformed)

# %%
reformed
# Out:
# 'i love you'

# %%
df['clean_tweet'] = df['clean_tweet'].apply(lambda x : ' '.join(d[word] if word in d else word for word in x.split()))

# %%
df['clean_tweet'][135]
# Out:
# 'Baseball season for the win Yankees This is where the love started'

# %%
#Removing stopwords
STOP_WORDS = nltk.corpus.stopwords.words('english')
newstop = [
"के",
"का",
"एक",
"में",
"की",
"है",
"यह",
"और",
"से",
"हैं",
"को",
"पर",
"इस",
"होता",
"कि",
"जो",
"कर",
"मे",
"गया",
"करने",
"किया",
"लिये",
"अपने",
"ने",
"बनी",
"नहीं",
"तो",
"ही",
"या",
"एवं",
"दिया",
"हो",
"इसका",
"था",
"द्वारा",
"हुआ",
"तक",
"साथ",
"करना",
"वाले",
"बाद",
"लिए",
"आप",
"कुछ",
"सकते",
"किसी",
"ये",
"इसके",
"सबसे",
"इसमें",
"थे",
"दो",
"होने",
"वह",
"वे",
"करते",
"बहुत",
"कहा",
"वर्ग",
"कई",
"करें",
"होती",
"अपनी",
"उनके",
"थी",
"यदि",
"हुई",
"जा",
"ना",
"इसे",
"कहते",
"जब",
"होते",
"कोई",
"हुए",
"व",
"न",
"अभी",
"जैसे",
"सभी",
"करता",
"उनकी",
"तरह",
"उस",
"आदि",
"कुल",
"एस",
"रहा",
"इसकी",
"सकता",
"रहे",
"उनका",
"इसी",
"रखें",
"अपना",
"पे",
 "क्या",
  "आये",
"उसके",
"कौन",
"देने ",
"कभी",
"आपने",
"क्यों",
"मिला",
"बोलो",
"चाहिए",
"भी",
"डालने",
"रखती",
"देखा",
"साल",
"हु",
"नही",
"लगा",
"वो",
"आपको",
"बजे",
"उसका",
"आया",
"फिर",
 "मेने",
 "इनके",
  "सामने",
   "झुक",
   "मनाई",
   "वैसे",
   "उठाया",
   "बोला",
   "रख","सोने", "दे", "काट",
   "बोला",
   "रख",
   "अब", 
   "गये",
   "सबका",
   "इसको",
      "ये",
    "समझ",
     "सका",
     "कैसे",
      "अगर",
      "तू",
      "क्यू",
       "चला",
        "जाता",
"तेरे",
"किसने",
"जी",
"बोले",
"होगा",
"वही",
 "जाती",
  "शुरू",
  "आज",
   "पूरे",
   "मारेगा" ,
   "आए",
   "अबे",
   "होतीं",
   "अबकी",
   "बार",
   "वाला",
    "बताने",
      "मै",
      "तुमको",
      "हूँ",
      "कह",
      "सब",
     "मना",
     "आ",
      "रही",
    "वरना",
     "कल",
     "सबके",
     "सब",
     " कह",
     "हर",
     "तुम",
     "बोल",
"आता",
 "इधर",
 "लगता","लेकिन", "तनिक",
 "अरे",
"रा",
 "है",
 "।",
 "देखो",
  "कितने",
  "निकलेगा",
  "है।",
  "तुने",
  "आपकी",
  "हे" ,
  "रे",
  "तूँ।",
  "तेरी",
  "जायेगी",
  "बनकर",
  "जाने",
  "तेरी",
  "बनाने",
  "गए",
  "जरा",
"करलो",
 "इतना",
  "ज्यादा",
   "कि",
   "करे",
   "देने",
   "यही",
   "हैं।",
   "तभी",
  "तुमने",
   "वालो",
   "हमने",
   ",",
   ".",
   "/",
   "-",
   "=",
   "#",
   "$",
   "!",
   ";",":","?","(",")","&","^","{","}","[","]",
   "*",
   "करके",
    "लिया",
     "गया।","यही",
  "ही","जाए","ली", "सारे",
  "उठाए",
  "र","तने","प", "जादां", "नू",
  "तुम्हारी", "चुकी",
  "तुझे", "हॆ","आयी", "तब", "तु",
  "ले","इनको" ,"देकर","करेगा",
  "इतनी", "उतनी","पहुंचा","इन्होंने",
   

]
STOP_WORDS.extend(newstop)

df['clean_tweet'] = df['clean_tweet'].str.lower().apply(lambda x : ' '.join([word for word in x.split() if not word in STOP_WORDS]))

# %%
df['clean_tweet'].isna().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (203, 3)

# %%
df['clean_tweet'][202]
# Out:
# 'jai shriiraam bhncod twittercomnationalvoice status'

# %%
#Lemmitization
lemmatizer = WordNetLemmatizer()
df['clean_tweet'] = df['clean_tweet'].apply(lambda x : ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# %%
#Stemming
ps = PorterStemmer()
adwait = df
#adwait.head()
df['clean_tweet'] = df['clean_tweet'].apply(lambda x : ' '.join([ps.stem(word) for word in x.split()]))

# %%
df.head()
# Out:
#                                                 text  value  \
# 0   मोदी क्या आये दीदी पटेल बोस भगत सिंह राज गुरु...      0
# 1                                  है कौन ये मादरचोद      1
# 2  आस्था के महापर्व छठी मे जो माँ अपने बच्चों के ...      0
# 3  वर्ष   में भारत सरकार द्वारा   अक्टूबर को प्रत...      0
# 4  केजरीवाल सरकार जो फ्री टिकट देने का ढिंढोरा पी...      0
#
#                                          clean_tweet
# 0  modii diidii pttel bo bhgt sinh raaj guru sukh...
# 1                                           maadrcod
# 2  aasthaa mhaaprv chtthii bccon nirjlaa vrt bcca...
# 3  vrss bhaart srkaar dvaaraa akttuubr prtivrss r...
# 4  kejriiva srkaar phrii ttiktt ddhinddhoraa piit...

# %%
#Tokenization
corpus = []
for i in range(0,200):
    tweet = df['clean_tweet'][i]
    tweet = tweet.lower()
    tweet = tweet.split()
    tweet = [ps.stem(word) for word in tweet if not       word in set(stopwords.words('english'))]
    tweet = ' '.join(tweet)
    corpus.append(tweet)

# %%
len(corpus)
# Out:
# 200

# %%
corpus
# Out:
# ['modii diidii pttel bo bhgt sinh raaj guru sukhdev nehruu bddaa mhaan',
#  'maadrcod',
#  'aasthaa mhaaprv chtthii bccon nirjlaa vrt bccaa plaayn maar jhel bett nikkmii srkaar',
#  'vrss bhaart srkaar dvaaraa akttuubr prtivrss raassttriiy ektaa div mnaan nirnni akttuubr vh bhaart maataa lauh puru srdaar pttel hiiraa',
#  'kejriiva srkaar phrii ttiktt ddhinddhoraa piitt sc jaani juddi laaiv',
#  'rupe jlaayaa kiimt mushkil ru baatii tel adhiktm ru prjvlit krmcaarii ru prti kiimt ruu yuupii srkaar lgbhg ru',
#  'biijepii shivsenaa gaandd laat maarn',
#  'uttr prdesh vishvaa jiitaa vikaa vishvaa ntiijaa griibii gyii uttr prdesh vikaa vishvaasghaat srkaar kmiyaan',
#  'gaandd ddnddaa kmjor',
#  'ttottii cor',
#  'puurvaancl bihaar mithilaa maithilii bhojpurii snsthaaon anurodh mukhymntrii arvind kejriiva ghossnnaaon sccaaii suucnaa adhikaar upyog jaankaarii praapt puurii smiikssaa vishvaa',
#  'rnddii porn sttaar aulaad prkaash raaj',
#  'modii raajaurii jvaanon divaalii',
#  'shaatir bhncod raag alaapn dhyaan httaan cuutiy',
#  'jnsnkhyaa bddhaao desh kbjaao bccaa ddonkttr injiiniyr aaiipii aaiiee useaarthik rup smpnn prntuabdul aatth bcce caahiy sttaa caabii votto hotii muurkhaurr abdul hoshiyaar srkaar',
#  'ciij ttuuttii librl gaandd biibii durbhaagi juddegii',
#  'desh kejriiva nphrt pyaar cunnaa nphrt cunaa hi bddhiy jnsnkhyaa niyntrnn nphrt phailaat',
#  'raat bje maadrcod',
#  'raajniitik chkkon rudaaliyon prm aavshyktaa rnddii ro ske mhaaraassttrhriyaannaa cunaav',
#  'saavrkr aangrejon mrvaa baap paakistaanii biryaanii bhosddii bkaitii pel',
#  'trk bhncod khitaab akbr muslmaanon',
#  'bcpn maadrcod mhaamaadrcod',
#  'raajsthaan srkaar uddeshi vikaa raajsthaan srkaar yojnaaon prtibddh aadrnniiy jnnaayk uddeshi yojnaaon laabh ghrghr ddhaannii ddhaannii phunc yojnaaon achuutaa',
#  'jhopddii khraamii bhddvaa porn paidaayi baap doglaa dhrm cott khuun hraamjaad gaandd maaregen bhddve',
#  'bhaaii gddaar srjiikl isttraaik cuutiyaa',
#  'vivaadit maadrcod hthiyaar bcaa khriiduungaa lndd',
#  'bhosddii kaaluu baap kongresii angrejo phryaad jhaattuumenttlaadmii',
#  'shj srl mrdubhaassii skriy jnnetaa mpr srkaar puurv mntrii vrisstt vidhaayk bdde bhaiyaa jnmdin ash bdhaaiiyaan muskura svsth vyst iishvr sudiirgh mnglmi jiivn kaanmnaa raam',
#  'modii aatnkvaad smaapt smaapt aatnkvaad smaapt jaahil aatnkvaad nett smaapt',
#  'bhddve shaantiduut pittaaii rnddii nrshn',
#  'modii prdhaanmntrii amit shaah bhaart shhnshaah amit shaah',
#  'kejriiva rgdd rgdd maaregaa kiirti aajaad drbhngiyaa sntoss guptaa drbhngiyaa',
#  'anucch astisv kendr shaasit prdesh jmmuu kshmiir lddaakh vikaa maarg prshst anusuucit aadivaasii smudaay anyaay ant bhaajpaa srkaar pryaason desh ektaa akhnddtaa suuri ug',
#  'kttue bhosddii hraamkhor kttuaa',
#  'mjaaron duaaen kbuul ksm shriiraam modii yogii',
#  'bhosddii gaalii avisskaar gaalii gaalii buraa maannaa',
#  'maadrcod',
#  'raajsthaan jodhpur naabaalig bccii blaatkaar drind sliim hd bhncod suvro blaatkaarii muslimo phaansii',
#  'httaaodeshbcaao rnddii vipkss',
#  'rnddii',
#  'bhvissi maadrcod',
#  'biijepii phnndd modii nehruu baavjuud',
#  'pttel modii pglii daadii naak daadii naak',
#  'yogii modii shaah bhaaii gnjeddii jnsnkhyaa niyntrnn',
#  'srdaar pttel modii khnaa',
#  'asptaal minimm mjduurii kejriiva cunaavii sttntt rinkiyaa paapaa',
#  'maadrcod biskutt ttaaphii laalc pngosii abbaa svaarthsiddhi ckkr jysiyaaraam',
#  'uttr puurvii dishaaon kejriiva caaro dishaaon ttaargett bhaart dhuvaa prdussnn nauttnkii gndgii kaarnn gai cainbr',
#  'maadr cod sih likh tnik bhncod dlit',
#  'muurkh bhaaii baap raa modii kpddaa paisaa',
#  'srkaar bson maarshl tainaatii sotii mhilaa surkssaakrmiyon dvaaraa surkssaa maarshl annuu',
#  'modii saamaajik nyaay purodhaa laalu yaadv phnsaakr',
#  'nijii knpniyon naak rgddtii bhaart srkaar srkaar krj bhaart khriidtii nijii knpniiyaan bhaart vrtmaan khtrnaak vhaattsep kaandd saaph bhaandd desh desh surkssit',
#  'cuutiyaa',
#  'prle drje cuutiyaa tuun dlaal miiddiyaa jhuutthii khbren dhraatl jutiyaatii socaa kaayd pitt amriikaa',
#  'kill shk gaandd maarii bhosddii',
#  'sushiil modii bihaar nitiish kumaar pichlguu bihaar biijepii srkaar nitiish kumaar bihaar bihaar aakraamk giriraaj sinh',
#  'mhbuubaa srkaar kshmiir ptthrbaajon prjaati vilupt adhyyn yuropiiy saasnd kshmiir',
#  'allaah gnndd lndd bhosddii mullaa lndd iid',
#  'modii srkaar eyrportt paayltton prshikssit rojgaar shhron gaanvon joddn hvaaii raast bhaajpaa srkaar desh hvaaii suvidhaa',
#  'rviish kumaar vaampnthii diimk phrjii udaarvaadii sekulr kaarykrtaaon htyaaon pkss udaar vaadiyon srkaar cuni caaht udaar vaadiyon',
#  'hiiro jnyaan aaiindaa gaandd snbhaal',
#  'hhhhh rnddii royegaa',
#  'rhnevaal puurvaancl vaashiyon gaalii denevaalaa beshrm muurkhmntrii kejriiva iid muslmaanon maalaama chtth puurvaancl vaashiyon ghaayl',
#  'lvddiyaa bkcodii bitthaa uddaa bhncod',
#  'prdhaanmntrii nrendr modii bhaassnn hiraast aadivaasii',
#  'dhrm baabaao pesh bhne bhosddii dhrm itihaa saal shnkr crsii blaatkaarii krssnnaa maantaa dhrm grnth pdd',
#  'bhaiyaa mettro kiraayaa kejriiva sbsiddii',
#  'ksm cuutiyaa bhosdiva',
#  'srkaar',
#  'gddaaron rottii bhaart rnddi paakistaan bnd huaaab desh',
#  'modii kejriiva snghputr raajniiti lphphaajii siimit',
#  'kejriiva kjrii nipttaayegaa',
#  'guru baink maadrcod',
#  'modii krodd jndhn khaat khol mudraa lon sbsiddii khaaton yojnaaon bainkr sailrii cuppii',
#  'bdlaa indiraa dngaa aajaad bhaart bhyaank dngaa jismen hjaaron beksuur siikh maar maarn kaangresii srkaar dngaa krmiyon surkssaa saadhn prdaan siikho srkaar dngaa krmiyon die',
#  'pttaakh jlaao pddosii raajyon jl praalii khilaaph tthiikraa kejriiva srkaar phodd paisa',
#  'snghii suar gaandd phtt modii pentt peshaab',
#  'kejriiva srkaar khuubsuurtii jnaab',
#  'bhosddii gaadd ghu',
#  'khudvaa cutiyaa kaattt',
#  'bhaart hkiikt srkaar niitiyon svaal njr bnd',
#  'r rnddii dussynt cauttaalaa jaadaan amit shaah tlve caattnn saal',
#  'kejriiva gndii raajniiti yuupii bihaar chtth rok nauttnkii vaaj',
#  'ktii cuutiyaa pttaakh paisa vaataavrnn khraab',
#  'mnoj bhiiyaa tmaashaa cutiyaa',
#  'svaagtyogykdm modii srkaar deshvaasiyo mndirmsjidgurudvaarocrco',
#  'laakh cl cukii orijnl saal hijddo graahk ddhuunddhtaa cutiyaa baap khaan phtte nirodh paidaaiish',
#  'shukr vaashbaisin pair gaandd',
#  'molvii gaandd mrvaak pedaa saal pedaaish',
#  'antrraassttriiy dlaal modii srkaar bhaart videsh kuuttniiti tmaashaa',
#  'dhrtii bojh bdduaa mriyo uksaayaa andh gobr paitth cuutiyaa pttaakh choddkr jaiso lnkaa dlaalii kmpttiishn bhaadd',
#  'bhosddii shkl suvr',
#  'bhncod hvn pnddit svaahaa',
#  'modii srkaar desh hvaaii sevaaen',
#  'phtt arvind kejriiva',
#  'ttonttii saalon khaalaaon sphaaii tthumk lgvaae',
#  'biijepii cunaav srjikl sttraaikbonrddr goliibaariiaatnkvaadii hmlaahinduumuslimmndirmsjid modii shaah jaan khtraa krtii kejriiva tmaam naakaam koshishon kejriiva paae',
#  'gaandd mraa bhoshriik',
#  'yshsvii prdhaanmntrii nrendr modii jmmuu kshmiir anucch httaan kotti kotti aabhaar',
#  'paidaaish maa laalu soii bgdaadii ttpkaa jaayegen cuddii todd rnddii bhtaar maaraa',
#  'wanna fuck bitch',
#  'fuck bitch start cri',
#  'fuck bro',
#  'idiot',
#  'bad bitch thing',
#  'bitch',
#  'fuck bitch even suck dick',
#  'nice girl bad naughti bad yello hoe real nice bodi south chick',
#  'love',
#  'hate',
#  'damn funni bitch',
#  'stupid realli belol look straight face',
#  'woof woof hot sol',
#  'wanna money fuck model bitch',
#  'queer gaywad',
#  'met pussi ocean dr gave pussi pill',
#  'trippi bitch fuck hennessi',
#  'god dickhead',
#  'wanna suck dick press boob',
#  'eat boob lick pussi',
#  'txt old bitch bitch pussi wetter',
#  'wear pushup bra boob support',
#  'meow meow pussi cat pussi cat',
#  'momma pussi cat insid doghou',
#  'eggplant emoji doe look scream lmao',
#  'press cloth damn irrit',
#  'prefer sex love',
#  'dat bitch scream doin sex',
#  'seh pussi wetter shower curtain',
#  'babi monkey bathtim',
#  'gay religion shouldnt mess',
#  'seem fuckin beauti gay',
#  'r beauti love',
#  'fuck gay blacklist hoe',
#  'baseb season win yank love start',
#  'im earli bird im night owl im wise worm',
#  'overdo heavi drug doesnt sound bad tonight pussi shit everi day',
#  'pit bull photograph love fairi tale creatur',
#  'long laker trash could careless real',
#  'didnt anyth tho kiss faggot',
#  'could fat bitch lap',
#  'isnt ghettoit smart im idc',
#  'want nose bad boi',
#  'peel peel bring back rewind back im move shaq',
#  'dirti foot bitch',
#  'play soccer cheat girl wear khaki colour cargo haircut',
#  'lmfaoooo hate black peopl',
#  'piss lad past lick dirti sol sleep',
#  'stay beauti bitch',
#  'pussi beauti boob hot nd dick erect',
#  'postapocalyptichero longer interest go touch pull pant',
#  'grope peopl public wasnt alreadi illegalwhat deutschland',
#  'woman arent allow arab countri',
#  'elect love muslim citizen take countri back respon happen',
#  'bunnysmind doesnt workit advi way protect',
#  'wear protect condom',
#  'obama tri hardest though merkel level yearold iraqi man convict sexual assault given oneyear suspend sentenc yearold algerian man convict abet sexual assault attempt assault given sentenc sound exactli obama tri black peopl countri away everyth',
#  'scientist know well mean pa law make legal castrat anim',
#  'look laid',
#  'true liber fashion ordin mean pass end rape muslim fatherland',
#  'edloweri oneyear suspend sentenc wow realli harsh',
#  'even though woman lie whole thinglol',
#  'lilli esin blue moon got choic crop chevrolet corvett stingray coup unavail laptop flash',
#  'nevergofulllib pa law know cau paper ink prevent crime',
#  'russian rape million woman child end wwii peopl contend bunch savag pathet countri cowtow hoard uncivil migrant take countri back germani',
#  'justthetruthnobodywantstohear work great bracelet hand touch liebral never learn hahahahahahaha',
#  'adler yeah thatll stop nasti rapist especi muslim',
#  'ignor troll one law prevent crime easier prosecut crimin good thing',
#  'impress peopl realli didnt anoth exampl merkelobama progressiv',
#  'islam countri rape woman consid dishonor famili subject beat famili subject honor kill',
#  'add thatif protect womenth prosecut scumbag',
#  'alway meant enforc law stop procrastin avoid job',
#  'thursday local court cologn hand first convict sexual offen year eve yearold iraqi man convict sexual assault given oneyear suspend sentenc yearold algerian man convict abet sexual assault attempt assault given sentenc aggress sentenc absolut certain deter behavior futur',
#  'goreagangothi reason sentenc one caveat name boil subhuman scumbag pig blood',
#  'gun control answerblack control answer',
#  'hundr woman rape molest year eve travesti one convict far becam problem germani open border hord womenh muslim',
#  'hard punish peopl view woman toy religion allow',
#  'religion cult hate death destruct',
#  'wrap mind around woman rape two video show say trial yeah european style justic america ventur guess opposit chang allow deport savag liber wing equiv democrat parti',
#  'first immigr seduc act hear jail submiss',
#  'rever discrimin big time perceiv problem dear leader intend remedi execut fiat anoth reason feder depart educ dole tax money make state jump hoop think enough enough',
#  'transgend peopl exist sinc begin time alway kept fact felt wrong gender secret suffer silenc live gender move locat obviou use bathroom gender live one knew unlik christian conserv didnt bathroom dress area flail gen italia around sudden problem polit awar peopl exist',
#  'christian reason care gay tg church pay huge fine right equal right',
#  'poll accur wayn pollster compet contract result focu accuraci problem predict elect within margin error coupl fox rasmussen republican hou effect around point coupl ppp dem hou effect around poll trump isnt well wor mccain romney time even fox poll',
#  'trump endor violenc liber compli wish gladli',
#  'hoe smoke loser yea ig',
#  'sex porn',
#  'bitch cut everyday',
#  'watch porn',
#  'porn ban',
#  'faggot nigga niggi',
#  'chipkali dimag bhosdi',
#  'harami sala gandu',
#  'haram kamai',
#  'gandu gand fadng teru chatni',
#  'pasin paseen chut',
#  'chudaikhana salo',
#  'jhaat aukad aajt gand maran gaandu sale',
#  'haram kamai waqt guroor']

# %%
normal_words = ' '.join([word for word in df['clean_tweet'][df['value'] == 0]])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 100).generate(normal_words)
print('Normal words')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# Normal words
# (-0.5, 799.5, 499.5, -0.5)

# %%
normal_words = ' '.join([word for word in df['clean_tweet'][df['value'] == 1]])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 100).generate(normal_words)
print('Normal words')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
# Out:
# Normal words
# (-0.5, 799.5, 499.5, -0.5)

# %%
df.head()
# Out:
#                                                 text  value  \
# 0   मोदी क्या आये दीदी पटेल बोस भगत सिंह राज गुरु...      0
# 1                                  है कौन ये मादरचोद      1
# 2  आस्था के महापर्व छठी मे जो माँ अपने बच्चों के ...      0
# 3  वर्ष   में भारत सरकार द्वारा   अक्टूबर को प्रत...      0
# 4  केजरीवाल सरकार जो फ्री टिकट देने का ढिंढोरा पी...      0
#
#                                          clean_tweet
# 0  modii diidii pttel bo bhgt sinh raaj guru sukh...
# 1                                           maadrcod
# 2  aasthaa mhaaprv chtthii bccon nirjlaa vrt bcca...
# 3  vrss bhaart srkaar dvaaraa akttuubr prtivrss r...
# 4  kejriiva srkaar phrii ttiktt ddhinddhoraa piit...

# %%
#TF-IDF approach
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2)
# TF-IDF feature matrix
X1 = tfidf_vectorizer.fit_transform(corpus)
Y1 = df.loc[:,'value'].values

# %%
from sklearn.model_selection import train_test_split
X1_train, X1_test, Y1_train, Y1_test = train_test_split(df['clean_tweet'], df['value'], test_size = 0.3, random_state=0, shuffle = True, stratify=df['value'])
vectorizer = tfidf_vectorizer
X1_train_vect = vectorizer.fit_transform(X1_train)
Y1 = df.loc[:,'value'].values

# %%
#Random Forest using pipelines
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
rf = Pipeline([('tfidf', TfidfVectorizer()), ('rf', RandomForestClassifier())])
rf.fit(X1_train, Y1_train)
y_pred = rf.predict(X1_test)
print(pd.crosstab(Y1_test,y_pred,rownames=['Actual'],colnames=['Predicted']))
print(classification_report(Y1_test, y_pred))
# Out:
# Predicted   0   1
# Actual
# 0          23   7
# 1           6  25
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78        30
#            1       0.78      0.81      0.79        31
#
#     accuracy                           0.79        61
#    macro avg       0.79      0.79      0.79        61
# weighted avg       0.79      0.79      0.79        61

# %%
df.to_csv('clean.csv')

# %%
df =  pd.read_csv("clean.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                               text  value  \
# 0           0   मोदी क्या आये दीदी पटेल बोस भगत सिंह राज गुरु...      0
# 1           1                                  है कौन ये मादरचोद      1
# 2           2  आस्था के महापर्व छठी मे जो माँ अपने बच्चों के ...      0
# 3           3  वर्ष   में भारत सरकार द्वारा   अक्टूबर को प्रत...      0
# 4           4  केजरीवाल सरकार जो फ्री टिकट देने का ढिंढोरा पी...      0
#
#                                          clean_tweet
# 0  modii diidii pttel bo bhgt sinh raaj guru sukh...
# 1                                           maadrcod
# 2  aasthaa mhaaprv chtthii bccon nirjlaa vrt bcca...
# 3  vrss bhaart srkaar dvaaraa akttuubr prtivrss r...
# 4  kejriiva srkaar phrii ttiktt ddhinddhoraa piit...

# %%
df.shape
# Out:
# (203, 4)

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df,test_size = 0.2, stratify = df['value'], random_state=21)

# get the shape of train and test split.
train.shape, test.shape
# Out:
# ((162, 4), (41, 4))

# %%
train.head()
# Out:
#      Unnamed: 0                                               text  value  \
# 63           63  दिल्ली में रहनेवाले पूर्वांचल वाशियों को गाली ...      0
# 200         200                              kameeni aurat chup kr      1
# 151         151  PostApocalypticHero why men no longer interest...      1
# 82           82  र रंडी़ बनना था तने तो दुष्यंत चौटाला   प चला ...      1
# 35           35  ये भोसड़ी वाला गाली का अविष्कार किसने किया और ...      1
#
#                                            clean_tweet
# 63   rhnevaal puurvaancl vaashiyon gaalii denevaala...
# 200                                 kameeni aurat chup
# 151  postapocalyptichero longer interest go touch p...
# 82   r rnddii dussynt cauttaalaa jaadaan amit shaah...
# 35   bhosddii gaalii avisskaar gaalii gaalii buraa ...

# %%
test.head()
# Out:
#      Unnamed: 0                                               text  value  \
# 80           80  खुदवा ली नहीं ये सारे जनता का चुतिया काटते हैं...      1
# 11           11                रंडी पोर्न स्टार की औलाद प्रकाश राज      1
# 121         121      i txt my old bitch my new bitch pussy wetter       1
# 111         111                        damn! You are a funny bitch      0
# 122         122                   wear pushup bra for boob support      0
#
#                                 clean_tweet
# 80                   khudvaa cutiyaa kaattt
# 11   rnddii porn sttaar aulaad prkaash raaj
# 121        txt old bitch bitch pussi wetter
# 111                        damn funni bitch
# 122            wear pushup bra boob support

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(lowercase= True, max_features=1000, stop_words=STOP_WORDS)

# fit the object with the training data tweets
tfidf_vectorizer.fit(train.clean_tweet)
# Out:
# TfidfVectorizer(max_features=1000,
#                 stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours',
#                             'ourselves', 'you', "you're", "you've", "you'll",
#                             "you'd", 'your', 'yours', 'yourself', 'yourselves',
#                             'he', 'him', 'his', 'himself', 'she', "she's",
#                             'her', 'hers', 'herself', 'it', "it's", 'its',
#                             'itself', ...])

# %%
train_idf = tfidf_vectorizer.transform(train.clean_tweet)
test_idf  = tfidf_vectorizer.transform(test.clean_tweet)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
model_LR = LogisticRegression()

# fit the model with the training data
model_LR.fit(train_idf, train.value)

# predict the label on the traning data
predict_train = model_LR.predict(train_idf)

# predict the model on the test data
predict_test = model_LR.predict(test_idf)

# f1 score on train data
f1_score(y_true= train.value, y_pred= predict_train)
## >> 0.4888178913738019

f1_score(y_true= test.value, y_pred= predict_test)
# Out:
# 0.7346938775510204

# %%
from sklearn.pipeline import Pipeline
pipeline = Pipeline(steps= [('tfidf', TfidfVectorizer(lowercase=True,
                                                      max_features=1000,
                                                      stop_words= STOP_WORDS)),
                            ('model', LogisticRegression())])

# fit the pipeline model with the training data                            
pipeline.fit(train.clean_tweet, train.value)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=1000,
#                                  stop_words=['i', 'me', 'my', 'myself', 'we',
#                                              'our', 'ours', 'ourselves', 'you',
#                                              "you're", "you've", "you'll",
#                                              "you'd", 'your', 'yours',
#                                              'yourself', 'yourselves', 'he',
#                                              'him', 'his', 'himself', 'she',
#                                              "she's", 'her', 'hers', 'herself',
#                                              'it', "it's", 'its', 'itself', ...])),
#                 ('model', LogisticRegression())])

# %%
text = ["Virat Kohli, AB de Villiers set to auction their 'Green Day' kits from 2016 IPL match to raise funds"]

# predict the label using the pipeline
pipeline.predict(text)
## >> array([0])
# Out:
# array([0], dtype=int64)

# %%
from joblib import dump

# dump the pipeline model
dump(pipeline, filename="text_classification.joblib")

# %%
from joblib import load

# sample tweet text
text = ["Virat Kohli, AB de Villiers set to auction their 'Green Day' kits from 2016 IPL match to raise funds"]

# load the saved pipleine model
pipeline = load("text_classification.joblib")

# predict on the sample tweet text
pipeline.predict(text)
